# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#BBC
user_bbc = "@BBCWorld"

counter = 1

BBC = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_bbc, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        BBC.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_bbc})

        counter += 1
        
BBC_pd = pd.DataFrame.from_dict(BBC)
BBC_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0    @BBCWorld    0.5859     0.703    0.000     0.297
# 1    @BBCWorld   -0.2500     0.818    0.182     0.000
# 2    @BBCWorld    0.0000     1.000    0.000     0.000
# 3    @BBCWorld   -0.1531     0.556    0.243     0.201
# 4    @BBCWorld    0.5106     0.708    0.000     0.292
#
#                                                Tweet  Tweets Ago
# 0  Is Russia the real winner of World Cup 2018? h...           1
# 1  Croatia's Luka Modric: Chequered past haunts W...           2
# 2  Trump's UK visit: Eight key moments https://t....           3
# 3  Good week, bad week: The people in the news ht...           4
# 4  The full story of Thailand’s extraordinary cav...           5

# %%
#CBS
user_cbs = "@CBSNews"

counter = 1
CBS = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_cbs, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        CBS.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_cbs})

        counter += 1
        
CBS_pd = pd.DataFrame.from_dict(CBS)
CBS_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0     @CBSNews    0.5106     0.852     0.00     0.148
# 1     @CBSNews    0.0000     1.000     0.00     0.000
# 2     @CBSNews    0.0000     1.000     0.00     0.000
# 3     @CBSNews   -0.5574     0.620     0.26     0.120
# 4     @CBSNews    0.0000     1.000     0.00     0.000
#
#                                                Tweet  Tweets Ago
# 0  Air Force One's current design was part of JFK...           1
# 1  The summit between President Trump and Russian...           2
# 2  Maryland officials say the FBI told them this ...           3
# 3  "The warning lights are blinking red": Nationa...           4
# 4  WATCH: Konza the giraffe calf was born at the ...           5

# %%
#FOX
user_fox = "@FoxNews"

counter = 1

FOX = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_fox, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        FOX.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_fox})

        counter += 1
        
FOX_pd = pd.DataFrame.from_dict(FOX)
FOX_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0     @FoxNews   -0.3182     0.897    0.103       0.0
# 1     @FoxNews    0.0000     1.000    0.000       0.0
# 2     @FoxNews    0.0000     1.000    0.000       0.0
# 3     @FoxNews   -0.5423     0.727    0.273       0.0
# 4     @FoxNews    0.0000     1.000    0.000       0.0
#
#                                                Tweet  Tweets Ago
# 0  "Ghost dunes" found on Mars could hold proof o...           1
# 1  Infant dies day after showing symptoms of meni...           2
# 2  The Daily Spike: Albie and the Harrell family ...           3
# 3  OPINION: Republicans walked right into Peter S...           4
# 4  Texas fishermen pull 8-foot alligator gar from...           5

# %%
#CNN
user_cnn = "@CNN"

counter = 1

CNN = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_cnn, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        CNN.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_cnn})

        counter += 1
CNN_pd = pd.DataFrame.from_dict(CNN)
CNN_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0         @CNN    0.3400     0.893      0.0     0.107
# 1         @CNN    0.2023     0.917      0.0     0.083
# 2         @CNN    0.5034     0.847      0.0     0.153
# 3         @CNN    0.5574     0.806      0.0     0.194
# 4         @CNN    0.0000     1.000      0.0     0.000
#
#                                                Tweet  Tweets Ago
# 0  Scarlett Johansson has opted to withdraw from ...           1
# 1  RT @AC360: .@JeffreyToobin: "Today is actually...           2
# 2  Seven in 10 registered voters say they're extr...           3
# 3  Republicans praise ex-FBI lawyer Lisa Page's t...           4
# 4  RT @OutFrontCNN: "It's as if your neighbor cam...           5

# %%
#NEW YORK TIMES
user_nyt = "@nytimes"

counter = 1

NYT = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_nyt, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        NYT.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_nyt})

        counter += 1
        
NYT_pd = pd.DataFrame.from_dict(NYT)
NYT_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0     @nytimes    0.0000     1.000    0.000     0.000
# 1     @nytimes    0.0000     1.000    0.000     0.000
# 2     @nytimes   -0.5574     0.854    0.146     0.000
# 3     @nytimes    0.1779     0.711    0.111     0.178
# 4     @nytimes    0.1280     0.696    0.125     0.179
#
#                                                Tweet  Tweets Ago
# 0  RT @katierogers: New QUEEN feature from me (w/...           1
# 1  Evening Briefing: Here's what you need to know...           2
# 2  Linda Daniels relied on an oxygen machine, and...           3
# 3  A village in Greenland is on alert amid fears ...           4
# 4  RT @maggieNYT: “The nation’s top intelligence ...           5

# %%
#SCATTER PLOTS

bbc_scatter = plt.scatter(BBC_pd["Tweets Ago"], BBC_pd["Compound"], marker="o", facecolors="lightseagreen", 
                          edgecolors="black", label = "BBC")
cbs_scatter = plt.scatter(CBS_pd["Tweets Ago"], CBS_pd["Compound"], marker="o", facecolors="green", 
                          edgecolors="black", label = "CBS")
fox_scatter = plt.scatter(FOX_pd["Tweets Ago"], FOX_pd["Compound"], marker="o", facecolors="blue", 
                          edgecolors="black", label="FOX")
nyt_scatter = plt.scatter(NYT_pd["Tweets Ago"], NYT_pd["Compound"], marker="o", facecolors="yellow",
                         edgecolors="black",label="NYT")
cnn_scatter = plt.scatter(CNN_pd["Tweets Ago"], CNN_pd["Compound"], marker="o", facecolors="red",
                         edgecolors="black", label="CNN")

plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.0), title="Media Sources")
plt.title("Sentiment Analysis of Media Tweets (07/13/2018)")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
nyt_scatter
plt.savefig("Sentiment_Analysis_Scatter.png")

# %%
bbc_mean = np.mean(BBC_pd["Compound"])
cbs_mean = np.mean(CBS_pd["Compound"])
cnn_mean = np.mean(CNN_pd["Compound"])
fox_mean = np.mean(FOX_pd["Compound"])
nyt_mean = np.mean(NYT_pd["Compound"])

means = [bbc_mean, cbs_mean, cnn_mean, fox_mean, nyt_mean]
users = ["BBC", "CBS", "CNN", "FOX", "NYT"]
colors = ["lightseagreen", "green", "red", "blue", "yellow"]

plt.title("Overall Media Sentiment based on Twitter (07/13/2018)")
plt.ylabel("Tweet Polarity")

plt.bar(users, means, color=colors, align="center")
plt.savefig("Overall_Media_Sentiment_Barchart.png")
