# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#BBC
user_bbc = "@BBCWorld"

counter = 1

BBC = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_bbc, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        BBC.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_bbc})

        counter += 1
        
BBC_pd = pd.DataFrame.from_dict(BBC)
BBC_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0    @BBCWorld   -0.2500     0.818    0.182     0.000
# 1    @BBCWorld    0.0000     1.000    0.000     0.000
# 2    @BBCWorld   -0.1531     0.556    0.243     0.201
# 3    @BBCWorld    0.5106     0.708    0.000     0.292
# 4    @BBCWorld    0.0000     1.000    0.000     0.000
#
#                                                Tweet  Tweets Ago
# 0  Croatia's Luka Modric: Chequered past haunts W...           1
# 1  Trump's UK visit: Eight key moments https://t....           2
# 2  Good week, bad week: The people in the news ht...           3
# 3  The full story of Thailand’s extraordinary cav...           4
# 4  US lawmaker caught speeding tells cop he often...           5

# %%
#CBS
user_cbs = "@CBSNews"

counter = 1
CBS = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_cbs, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        CBS.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_cbs})

        counter += 1
        
CBS_pd = pd.DataFrame.from_dict(CBS)
CBS_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0     @CBSNews    0.0000     1.000    0.000      0.00
# 1     @CBSNews    0.0000     1.000    0.000      0.00
# 2     @CBSNews   -0.5574     0.620    0.260      0.12
# 3     @CBSNews    0.0000     1.000    0.000      0.00
# 4     @CBSNews   -0.2960     0.855    0.145      0.00
#
#                                                Tweet  Tweets Ago
# 0  The summit between President Trump and Russian...           1
# 1  Maryland officials say the FBI told them this ...           2
# 2  "The warning lights are blinking red": Nationa...           3
# 3  WATCH: Konza the giraffe calf was born at the ...           4
# 4  Where's the beef? WeWork will stop expensing a...           5

# %%
#FOX
user_fox = "@FoxNews"

counter = 1

FOX = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_fox, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        FOX.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_fox})

        counter += 1
        
FOX_pd = pd.DataFrame.from_dict(FOX)
FOX_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0     @FoxNews   -0.5423     0.727    0.273       0.0
# 1     @FoxNews    0.0000     1.000    0.000       0.0
# 2     @FoxNews    0.0000     1.000    0.000       0.0
# 3     @FoxNews   -0.4019     0.803    0.197       0.0
# 4     @FoxNews   -0.7003     0.507    0.493       0.0
#
#                                                Tweet  Tweets Ago
# 0  OPINION: Republicans walked right into Peter S...           1
# 1  Texas fishermen pull 8-foot alligator gar from...           2
# 2  MLB suspends Papa John's promotion until after...           3
# 3  OPINION: Indictment arguments aside, Trump is ...           4
# 4  Florida beaches closed after shark attacks lea...           5

# %%
#CNN
user_cnn = "@CNN"

counter = 1

CNN = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_cnn, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        CNN.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_cnn})

        counter += 1
CNN_pd = pd.DataFrame.from_dict(CNN)
CNN_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0         @CNN    0.5574     0.806    0.000     0.194
# 1         @CNN    0.0000     1.000    0.000     0.000
# 2         @CNN   -0.7269     0.775    0.225     0.000
# 3         @CNN    0.0000     1.000    0.000     0.000
# 4         @CNN   -0.5106     0.864    0.136     0.000
#
#                                                Tweet  Tweets Ago
# 0  Republicans praise ex-FBI lawyer Lisa Page's t...           1
# 1  RT @OutFrontCNN: "It's as if your neighbor cam...           2
# 2  RT @AC360: Journalist @carlbernstein on Russia...           3
# 3  Former CIA Director Michael Hayden said he ant...           4
# 4  RT @AC360: Former Hillary Clinton campaign man...           5

# %%
#NEW YORK TIMES
user_nyt = "@nytimes"

counter = 1

NYT = []

oldest_tweet = None

for x in range(5):

    public_tweets = api.user_timeline(user_nyt, max_id = oldest_tweet)
        
    for tweet in public_tweets:
        
        text = tweet["text"]
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        oldest_tweet = tweet['id'] - 1
        
        NYT.append({"Tweet": text,
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": counter, 
                    "Account Name": user_nyt})

        counter += 1
        
NYT_pd = pd.DataFrame.from_dict(NYT)
NYT_pd.head()
# Out:
#   Account Name  Compound  Negative  Neutral  Positive  \
# 0     @nytimes    0.0000     1.000    0.000     0.000
# 1     @nytimes   -0.5574     0.854    0.146     0.000
# 2     @nytimes    0.1779     0.711    0.111     0.178
# 3     @nytimes    0.1280     0.696    0.125     0.179
# 4     @nytimes    0.4215     0.851    0.000     0.149
#
#                                                Tweet  Tweets Ago
# 0  Evening Briefing: Here's what you need to know...           1
# 1  Linda Daniels relied on an oxygen machine, and...           2
# 2  A village in Greenland is on alert amid fears ...           3
# 3  RT @maggieNYT: “The nation’s top intelligence ...           4
# 4  You might get one last opportunity to see Manh...           5

# %%
#SCATTER PLOTS

bbc_scatter = plt.scatter(BBC_pd["Tweets Ago"], BBC_pd["Compound"], marker="o", facecolors="lightseagreen", 
                          edgecolors="black", label = "BBC")
cbs_scatter = plt.scatter(CBS_pd["Tweets Ago"], CBS_pd["Compound"], marker="o", facecolors="green", 
                          edgecolors="black", label = "CBS")
fox_scatter = plt.scatter(FOX_pd["Tweets Ago"], FOX_pd["Compound"], marker="o", facecolors="blue", 
                          edgecolors="black", label="FOX")
nyt_scatter = plt.scatter(NYT_pd["Tweets Ago"], NYT_pd["Compound"], marker="o", facecolors="yellow",
                         edgecolors="black",label="NYT")
cnn_scatter = plt.scatter(CNN_pd["Tweets Ago"], CNN_pd["Compound"], marker="o", facecolors="red",
                         edgecolors="black", label="CNN")

plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.0), title="Media Sources")
plt.title("Sentiment Analysis of Media Tweets (07/13/2018)")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
nyt_scatter

# %%
bbc_mean = np.mean(BBC_pd["Compound"])
cbs_mean = np.mean(CBS_pd["Compound"])
cnn_mean = np.mean(CNN_pd["Compound"])
fox_mean = np.mean(FOX_pd["Compound"])
nyt_mean = np.mean(NYT_pd["Compound"])

means = [bbc_mean, cbs_mean, cnn_mean, fox_mean, nyt_mean]
users = ["BBC", "CBS", "CNN", "FOX", "NYT"]
colors = ["lightseagreen", "green", "red", "blue", "yellow"]

plt.title("Overall Media Sentiment based on Twitter (07/13/2018)")
plt.ylabel("Tweet Polarity")

plt.bar(users, means, color=colors, align="center")
# Out:
# <BarContainer object of 5 artists>
